# %% [markdown]
# <a href="https://colab.research.google.com/github/Amulya-NRIdegree/Mini-project-/blob/main/Introduction%20to%20Data%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
 for _ in range(1000):
     a1.append(random.randint(0,100))
     a2.append(random.randint(50,70))
     a3.append(random.randint(10,20))
     a4.append(random.randint(5,10))
     a5.append(random.randint(20,80))

# %%
df = {
      'grade':a1,
      'weight':a2,
      'friends':a3,
      'cousins':a4,
      'projects':a5
}

# %%
df
# Out:
# {'grade': [84,
#   64,
#   40,
#   11,
#   90,
#   10,
#   72,
#   19,
#   9,
#   76,
#   67,
#   74,
#   73,
#   20,
#   22,
#   67,
#   95,
#   28,
#   62,
#   68,
#   22,
#   1,
#   94,
#   74,
#   31,
#   56,
#   23,
#   36,
#   20,
#   21,
#   81,
#   17,
#   39,
#   1,
#   31,
#   52,
#   80,
#   13,
#   72,
#   72,
#   99,
#   96,
#   52,
#   71,
#   15,
#   42,
#   85,
#   44,
#   6,
#   52,
#   67,
#   26,
#   97,
#   30,
#   57,
#   37,
#   24,
#   83,
#   40,
#   99,
#   2,
#   47,
#   53,
#   31,
#   53,
#   54,
#   87,
#   90,
#   63,
#   70,
#   58,
#   29,
#   31,
#   95,
#   66,
#   43,
#   36,
#   32,
#   0,
#   15,
#   93,
#   71,
#   73,
#   2,
#   82,
#   84,
#   62,
#   31,
#   36,
#   15,
#   8,
#   56,
#   42,
#   46,
#   39,
#   53,
#   60,
#   89,
#   1,
#   90,
#   2,
#   94,
#   55,
#   31,
#   41,
#   99,
#   63,
#   90,
#   27,
#   43,
#   61,
#   44,
#   15,
#   76,
#   84,
#   30,
#   97,
#   63,
#   46,
#   65,
#   39,
#   33,
#   20,
#   98,
#   36,
# ...

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       84      60       10        5        38
# 1       64      70       10        9        57
# 2       40      65       12       10        24
# 3       11      50       19        5        50
# 4       90      61       19        9        47
# ..     ...     ...      ...      ...       ...
# 995     66      69       15       10        71
# 996     92      53       15       10        50
# 997     67      67       14        7        39
# 998     25      56       18        7        56
# 999     99      55       19        9        41
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight     friends      cousins     projects
# count  1000.000000  1000.000000  1000.00000  1000.000000  1000.000000
# mean     50.534000    59.798000    15.08700     7.489000    50.158000
# std      29.425273     5.910171     3.10533     1.754125    17.536549
# min       0.000000    50.000000    10.00000     5.000000    20.000000
# 25%      25.000000    55.000000    12.00000     6.000000    35.000000
# 50%      52.000000    60.000000    15.00000     7.000000    50.000000
# 75%      75.250000    65.000000    18.00000     9.000000    65.000000
# max     100.000000    70.000000    20.00000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
 friends15 = df1['friends'] > 15

# %%
 df1[friends15]
# Out:
#      grade  weight  friends  cousins  projects
# 3       11      50       19        5        50
# 4       90      61       19        9        47
# 9       76      55       20        5        67
# 13      20      65       18        6        45
# 16      95      63       16        9        23
# ..     ...     ...      ...      ...       ...
# 988     23      70       19        5        62
# 991     60      58       19        6        47
# 993     98      62       18        7        26
# 998     25      56       18        7        56
# 999     99      55       19        9        41
#
# [460 rows x 5 columns]

# %%
grade50 = df1['grade'] > 50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       84      60       10        5        38
# 1       64      70       10        9        57
# 4       90      61       19        9        47
# 6       72      52       13        8        58
# 9       76      55       20        5        67
# ..     ...     ...      ...      ...       ...
# 993     98      62       18        7        26
# 995     66      69       15       10        71
# 996     92      53       15       10        50
# 997     67      67       14        7        39
# 999     99      55       19        9        41
#
# [515 rows x 5 columns]

# %%
df1[friends15 & grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 4       90      61       19        9        47
# 9       76      55       20        5        67
# 16      95      63       16        9        23
# 30      81      58       17        9        46
# 35      52      54       17        9        47
# ..     ...     ...      ...      ...       ...
# 982     81      65       19        5        57
# 986     58      51       18       10        28
# 991     60      58       19        6        47
# 993     98      62       18        7        26
# 999     99      55       19        9        41
#
# [237 rows x 5 columns]

# %%
df1[friends15 & grade50].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 51     50      18       5        23          1
# 86     52      18       6        20          1
# 83     56      18       8        35          1
#        57      20       10       66          1
#        58      20       5        75          1
#                                             ..
# 67     57      17       9        62          1
#        60      18       6        34          1
# 68     59      17       7        50          1
# 69     55      17       6        76          1
# 100    67      16       9        65          1
# Name: count, Length: 237, dtype: int64

# %%
df1[friends15 & grade50]['friends'].value_counts()
# Out:
# friends
# 16    52
# 20    50
# 17    50
# 18    44
# 19    41
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friends15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friends15 & grade50].plot(x = 'grade',y ='projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friends15 & grade50].plot(x = 'grade',y ='projects',kind = 'pie')
# Out:
# <Axes: ylabel='projects'>

# %%
df1[friends15 & grade50].plot(x = 'grade',y ='projects', kind = 'scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friends15 & grade50].plot(x = ['grade','friends'],y = ['projects','weight'],kind = 'scatter', title = 'Sample Graph')
# Out:
# <Axes: title={'center': 'Sample Graph'}, xlabel='[grade, friends]', ylabel='[projects, weight]'>

# %%
 pip install matplotlib

# %%
 fdf = df1[friends15 & grade50]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 4       90      61       19        9        47
# 9       76      55       20        5        67
# 16      95      63       16        9        23
# 30      81      58       17        9        46
# 35      52      54       17        9        47
# ..     ...     ...      ...      ...       ...
# 982     81      65       19        5        57
# 986     58      51       18       10        28
# 991     60      58       19        6        47
# 993     98      62       18        7        26
# 999     99      55       19        9        41
#
# [237 rows x 5 columns]

# %%
df1.to_csv('/python-apt.tar.xz.csv')
